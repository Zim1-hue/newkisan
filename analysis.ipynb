# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\mohas\\Downloads\\new kisan\\new kisan'

# %%
os.listdir()
# Out:
# ['.gitignore',
#  '.orchids',
#  'analysis.ipynb',
#  'Complete_Technical_Analysis.md',
#  'confusion_matrix.csv',
#  'crop_prediction_evaluation.json',
#  'Crop_Prediction_Performance_Evaluation.md',
#  'dist',
#  'eslint.config.js',
#  'evaluate_crop_model.js',
#  'evaluate_model_simple.js',
#  'evaluate_rf_model.js',
#  'final_performance_evaluation.js',
#  'fix_rf_compatibility.js',
#  'full_confusion_matrix.json',
#  'generate_confusion_matrix.js',
#  'index.html',
#  'model_comparison_experiment.js',
#  'Model_Comparison_Experiment_Report.md',
#  'model_comparison_experiment_v2.js',
#  'model_comparison_final.js',
#  'Model_Comparison_Final_Report.md',
#  'model_comparison_final_results.json',
#  'model_comparison_results.json',
#  'model_comparison_results_v2.json',
#  'model_evaluation_simple.json',
#  'node_modules',
#  'package-lock.json',
#  'package.json',
#  'postcss.config.js',
#  'public',
#  'Random_Forest_Confusion_Matrix_Report.md',
#  'README.md',
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\mohas\\Downloads\\new kisan\\new kisan'

# %%
import os
os.listdir()
# Out:
# ['.gitignore',
#  '.orchids',
#  'analysis.ipynb',
#  'Complete_Technical_Analysis.md',
#  'confusion_matrix.csv',
#  'crop_prediction_evaluation.json',
#  'Crop_Prediction_Performance_Evaluation.md',
#  'dist',
#  'eslint.config.js',
#  'evaluate_crop_model.js',
#  'evaluate_model_simple.js',
#  'evaluate_rf_model.js',
#  'final_performance_evaluation.js',
#  'fix_rf_compatibility.js',
#  'full_confusion_matrix.json',
#  'generate_confusion_matrix.js',
#  'index.html',
#  'model_comparison_experiment.js',
#  'Model_Comparison_Experiment_Report.md',
#  'model_comparison_experiment_v2.js',
#  'model_comparison_final.js',
#  'Model_Comparison_Final_Report.md',
#  'model_comparison_final_results.json',
#  'model_comparison_results.json',
#  'model_comparison_results_v2.json',
#  'model_evaluation_simple.json',
#  'node_modules',
#  'package-lock.json',
#  'package.json',
#  'postcss.config.js',
#  'public',
#  'Random_Forest_Confusion_Matrix_Report.md',
#  'README.md',
# ...

# %%
import pandas as pd

data = pd.read_csv("confusion_matrix.csv")
data.head()
# Out:
#   Actual  Predicted  Count
# 0  apple      apple      0
# 1  apple     banana      0
# 2  apple  blackgram      0
# 3  apple   chickpea      0
# 4  apple    coconut      0

# %%
import pandas as pd
import json

with open("model_comparison_final_results.json") as f:
    data = json.load(f)

data
# Out:
# {'datasetInfo': {'totalSamples': 2200,
#   'features': 7,
#   'classes': 22,
#   'trainSamples': 1760,
#   'testSamples': 440,
#   'classOrder': ['apple',
#    'banana',
#    'blackgram',
#    'chickpea',
#    'coconut',
#    'coffee',
#    'cotton',
#    'grapes',
#    'jute',
#    'kidneybeans',
#    'lentil',
#    'maize',
#    'mango',
#    'mothbeans',
#    'mungbean',
#    'muskmelon',
#    'orange',
#    'papaya',
#    'pigeonpeas',
#    'pomegranate',
#    'rice',
#    'watermelon']},
#  'models': {'decisionTree': {'accuracy': 99.31818181818181,
#    'correct': 437,
#    'total': 440,
#    'trainingTimeMs': 3648.6232,
#    'predictionTimeMs': 0.6980999999996129,
#    'parameters': {'maxDepth': 10, 'minNumSamples': 3}},
#   'knn': {'accuracy': 97.72727272727273,
#    'correct': 430,
#    'total': 440,
#    'trainingTimeMs': 5.547399999999925,
#    'predictionTimeMs': 206.14869999999974,
#    'parameters': {'k': 5}},
#   'randomForest': {'accuracy': 99.77272727272727,
# ...

# %%
import pandas as pd

df = pd.DataFrame(data["models"])
df
# Out:
#                                           decisionTree        knn  \
# accuracy                                     99.318182  97.727273
# correct                                            437        430
# total                                              440        440
# trainingTimeMs                               3648.6232     5.5474
# predictionTimeMs                                0.6981   206.1487
# parameters        {'maxDepth': 10, 'minNumSamples': 3}   {'k': 5}
#
#                                                        randomForest
# accuracy                                                  99.772727
# correct                                                         439
# total                                                           440
# trainingTimeMs                                                    0
# predictionTimeMs                                             7.3872
# parameters        {'nEstimators': 50, 'maxDepth': 10, 'maxFeatur...

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(df["name"], df["accuracy"])
plt.title("Model Accuracy Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns
# Out:
# Index(['decisionTree', 'knn', 'randomForest'], dtype='object')

# %%
df.head()
# Out:
#                  decisionTree        knn randomForest
# accuracy            99.318182  97.727273    99.772727
# correct                   437        430          439
# total                     440        440          440
# trainingTimeMs      3648.6232     5.5474            0
# predictionTimeMs       0.6981   206.1487       7.3872

# %%
print(df)
print(df.columns)
# Out:
#                                           decisionTree        knn  \
# accuracy                                     99.318182  97.727273
# correct                                            437        430
# total                                              440        440
# trainingTimeMs                               3648.6232     5.5474
# predictionTimeMs                                0.6981   206.1487
# parameters        {'maxDepth': 10, 'minNumSamples': 3}   {'k': 5}
#
#                                                        randomForest
# accuracy                                                  99.772727
# correct                                                         439
# total                                                           440
# trainingTimeMs                                                    0
# predictionTimeMs                                             7.3872
# parameters        {'nEstimators': 50, 'maxDepth': 10, 'maxFeatur...
# ...

# %%
df = df.T
df
# Out:
#                accuracy correct total trainingTimeMs predictionTimeMs  \
# decisionTree  99.318182     437   440      3648.6232           0.6981
# knn           97.727273     430   440         5.5474         206.1487
# randomForest  99.772727     439   440              0           7.3872
#
#                                                      parameters
# decisionTree               {'maxDepth': 10, 'minNumSamples': 3}
# knn                                                    {'k': 5}
# randomForest  {'nEstimators': 50, 'maxDepth': 10, 'maxFeatur...

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(df.index, df["accuracy"])
plt.title("Model Accuracy Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy (%)")
plt.show()

# %%
plt.figure()
plt.bar(df.index, df["trainingTimeMs"])
plt.title("Training Time Comparison")
plt.xlabel("Models")
plt.ylabel("Time (ms)")
plt.show()

# %%
df["accuracy_percent"] = df["accuracy"]

# %%
plt.figure()
plt.bar(df.index, df["accuracy_percent"])
plt.title("Model Accuracy (%)")
plt.show()
